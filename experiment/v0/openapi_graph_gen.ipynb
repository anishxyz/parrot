# %%
# !pip install pydantic anytree networkx matplotlib inflect openapi-core jsonref
# Out:
# Requirement already satisfied: pydantic in /Users/anishagrawal/Desktop/Development/parrot/venv/lib/python3.11/site-packages (2.8.2)
# Requirement already satisfied: anytree in /Users/anishagrawal/Desktop/Development/parrot/venv/lib/python3.11/site-packages (2.12.1)
# Requirement already satisfied: networkx in /Users/anishagrawal/Desktop/Development/parrot/venv/lib/python3.11/site-packages (3.3)
# Requirement already satisfied: matplotlib in /Users/anishagrawal/Desktop/Development/parrot/venv/lib/python3.11/site-packages (3.9.1)
# Requirement already satisfied: inflect in /Users/anishagrawal/Desktop/Development/parrot/venv/lib/python3.11/site-packages (7.3.1)
# Requirement already satisfied: openapi-core in /Users/anishagrawal/Desktop/Development/parrot/venv/lib/python3.11/site-packages (0.19.2)
# Requirement already satisfied: jsonref in /Users/anishagrawal/Desktop/Development/parrot/venv/lib/python3.11/site-packages (1.1.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /Users/anishagrawal/Desktop/Development/parrot/venv/lib/python3.11/site-packages (from pydantic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /Users/anishagrawal/Desktop/Development/parrot/venv/lib/python3.11/site-packages (from pydantic) (2.20.1)
# Requirement already satisfied: typing-extensions>=4.6.1 in /Users/anishagrawal/Desktop/Development/parrot/venv/lib/python3.11/site-packages (from pydantic) (4.12.2)
# Requirement already satisfied: six in /Users/anishagrawal/Desktop/Development/parrot/venv/lib/python3.11/site-packages (from anytree) (1.16.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/anishagrawal/Desktop/Development/parrot/venv/lib/python3.11/site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /Users/anishagrawal/Desktop/Development/parrot/venv/lib/python3.11/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/anishagrawal/Desktop/Development/parrot/venv/lib/python3.11/site-packages (from matplotlib) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/anishagrawal/Desktop/Development/parrot/venv/lib/python3.11/site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy>=1.23 in /Users/anishagrawal/Desktop/Development/parrot/venv/lib/python3.11/site-packages (from matplotlib) (2.0.0)
# Requirement already satisfied: packaging>=20.0 in /Users/anishagrawal/Desktop/Development/parrot/venv/lib/python3.11/site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in /Users/anishagrawal/Desktop/Development/parrot/venv/lib/python3.11/site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/anishagrawal/Desktop/Development/parrot/venv/lib/python3.11/site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/anishagrawal/Desktop/Development/parrot/venv/lib/python3.11/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: more-itertools>=8.5.0 in /Users/anishagrawal/Desktop/Development/parrot/venv/lib/python3.11/site-packages (from inflect) (10.3.0)
# Requirement already satisfied: typeguard>=4.0.1 in /Users/anishagrawal/Desktop/Development/parrot/venv/lib/python3.11/site-packages (from inflect) (4.3.0)
# Requirement already satisfied: isodate in /Users/anishagrawal/Desktop/Development/parrot/venv/lib/python3.11/site-packages (from openapi-core) (0.6.1)
# Requirement already satisfied: jsonschema<5.0.0,>=4.18.0 in /Users/anishagrawal/Desktop/Development/parrot/venv/lib/python3.11/site-packages (from openapi-core) (4.22.0)
# Requirement already satisfied: jsonschema-path<0.4.0,>=0.3.1 in /Users/anishagrawal/Desktop/Development/parrot/venv/lib/python3.11/site-packages (from openapi-core) (0.3.3)
# Requirement already satisfied: openapi-schema-validator<0.7.0,>=0.6.0 in /Users/anishagrawal/Desktop/Development/parrot/venv/lib/python3.11/site-packages (from openapi-core) (0.6.2)
# Requirement already satisfied: openapi-spec-validator<0.8.0,>=0.7.1 in /Users/anishagrawal/Desktop/Development/parrot/venv/lib/python3.11/site-packages (from openapi-core) (0.7.1)
# Requirement already satisfied: parse in /Users/anishagrawal/Desktop/Development/parrot/venv/lib/python3.11/site-packages (from openapi-core) (1.20.2)
# Requirement already satisfied: werkzeug in /Users/anishagrawal/Desktop/Development/parrot/venv/lib/python3.11/site-packages (from openapi-core) (3.0.3)
# Requirement already satisfied: attrs>=22.2.0 in /Users/anishagrawal/Desktop/Development/parrot/venv/lib/python3.11/site-packages (from jsonschema<5.0.0,>=4.18.0->openapi-core) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/anishagrawal/Desktop/Development/parrot/venv/lib/python3.11/site-packages (from jsonschema<5.0.0,>=4.18.0->openapi-core) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/anishagrawal/Desktop/Development/parrot/venv/lib/python3.11/site-packages (from jsonschema<5.0.0,>=4.18.0->openapi-core) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/anishagrawal/Desktop/Development/parrot/venv/lib/python3.11/site-packages (from jsonschema<5.0.0,>=4.18.0->openapi-core) (0.18.1)
# Requirement already satisfied: PyYAML>=5.1 in /Users/anishagrawal/Desktop/Development/parrot/venv/lib/python3.11/site-packages (from jsonschema-path<0.4.0,>=0.3.1->openapi-core) (6.0.1)
# Requirement already satisfied: pathable<0.5.0,>=0.4.1 in /Users/anishagrawal/Desktop/Development/parrot/venv/lib/python3.11/site-packages (from jsonschema-path<0.4.0,>=0.3.1->openapi-core) (0.4.3)
# Requirement already satisfied: requests<3.0.0,>=2.31.0 in /Users/anishagrawal/Desktop/Development/parrot/venv/lib/python3.11/site-packages (from jsonschema-path<0.4.0,>=0.3.1->openapi-core) (2.32.3)
# Requirement already satisfied: rfc3339-validator in /Users/anishagrawal/Desktop/Development/parrot/venv/lib/python3.11/site-packages (from openapi-schema-validator<0.7.0,>=0.6.0->openapi-core) (0.1.4)
# Requirement already satisfied: lazy-object-proxy<2.0.0,>=1.7.1 in /Users/anishagrawal/Desktop/Development/parrot/venv/lib/python3.11/site-packages (from openapi-spec-validator<0.8.0,>=0.7.1->openapi-core) (1.10.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Users/anishagrawal/Desktop/Development/parrot/venv/lib/python3.11/site-packages (from werkzeug->openapi-core) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/anishagrawal/Desktop/Development/parrot/venv/lib/python3.11/site-packages (from requests<3.0.0,>=2.31.0->jsonschema-path<0.4.0,>=0.3.1->openapi-core) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/anishagrawal/Desktop/Development/parrot/venv/lib/python3.11/site-packages (from requests<3.0.0,>=2.31.0->jsonschema-path<0.4.0,>=0.3.1->openapi-core) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/anishagrawal/Desktop/Development/parrot/venv/lib/python3.11/site-packages (from requests<3.0.0,>=2.31.0->jsonschema-path<0.4.0,>=0.3.1->openapi-core) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/anishagrawal/Desktop/Development/parrot/venv/lib/python3.11/site-packages (from requests<3.0.0,>=2.31.0->jsonschema-path<0.4.0,>=0.3.1->openapi-core) (2024.7.4)
#
# [notice] A new release of pip available: 22.3.1 -> 24.1.2
# [notice] To update, run: pip install --upgrade pip

# %%
import logging

logging.basicConfig(level=logging.DEBUG, format='%(asctime)s - %(levelname)s - %(message)s')

# %%
# parse openapi
import json
import jsonref

def parse_spec(file_path):
    with open(file_path, 'r') as file:
        return jsonref.load(file)

# %%
from pydantic import BaseModel
from typing import List, Optional


class GraphNode(BaseModel):
    asset_name: str
    dependent_assets: List[str]
    inputs: List[str]
    route: str
    method: str
    tag: Optional[str]

# %%
# helpers
import re
import json
from collections import defaultdict
import re
from inflect import engine

def resolve_schema_ref(spec, schema):
    if isinstance(schema, dict):
        # if '$ref' in schema:
        #     ref = schema['$ref']
        #     parts = ref.split('/')
        #     current = spec
        #     for part in parts[1:]:  # Skip the first '#' part
        #         current = current[part]
        #     return resolve_schema_ref(spec, current)

        resolved_schema = {}
        for key, value in schema.items():
            if key in ['oneOf', 'allOf', 'anyOf']:
                resolved_schema[key] = [resolve_schema_ref(spec, item) for item in value]
            elif isinstance(value, dict):
                resolved_schema[key] = resolve_schema_ref(spec, value)
            elif isinstance(value, list):
                resolved_schema[key] = [resolve_schema_ref(spec, item) if isinstance(item, dict) else item for item in value]
            else:
                resolved_schema[key] = value
        return resolved_schema
    elif isinstance(schema, list):
        return [resolve_schema_ref(spec, item) for item in schema]
    else:
        return schema

def standardize_asset_name(name: str) -> str:
    # Initialize inflect engine for handling plurals
    p = engine()

    # Convert to lowercase and replace underscores with dashes
    name = name.lower().replace('_', '-')
    name = name.lower().replace(' ', '-')

    # Remove any non-alphanumeric characters (except dashes)
    name = re.sub(r'[^a-z0-9-]', '', name)

    # Split the name into parts
    parts = name.split('-')

    # Singularize each part
    invariant_words = {'synthesis', 'analysis', 'basis', 'thesis'}

    parts = [part if part in invariant_words else (p.singular_noun(part) or part) for part in parts]

    # Join the parts back together
    standardized_name = '-'.join(parts)

    # Remove 'id' or 'ids' if it's at the end of the name
    standardized_name = re.sub(r'-ids?$', '', standardized_name)
    return standardized_name

def get_last_route_segment(route: str) -> str:
    # Split the route by '/' and get the last non-empty segment
    segments = route.strip('/').split('/')
    last_segment = segments[-1] if segments else ''

    # If the last segment is surrounded by curly braces, remove them
    return re.sub(r'^\{(.*)\}$', r'\1', last_segment)

def last_part_has_id(route: str) -> bool:
    # Split the route into parts
    parts = route.strip('/').split('/')

    # Get the last part
    last_part = parts[-1] if parts else ''

    # Check if the last part is enclosed in curly braces or ends with '_id'
    return bool(re.match(r'^\{.*\}$', last_part) or last_part.endswith('_id'))

# %%
def organize_resources(spec):
    node_registry = {}

    get_assets = set()
    dependent_assets = set()
    all_tags = set()

    for path, methods in spec['paths'].items():
        if last_part_has_id(path):
            continue

        for method, details in methods.items():
            try:
                print("here", get_last_route_segment(path))
                if method in ["get"]:
                    get_assets.add(standardize_asset_name(get_last_route_segment(path)))
    
                if method not in ["post"] or last_part_has_id(path) : # maybe add `patch`
                    continue
    
                tags = details.get("tags")
    
                dependents = set()
                inputs = set()
    
                bad_ids = ["account_id", "x-selected-account-id"]
    
                def handle_properties(_properties):
                    for _input in _properties:
                        handle_input(_input)
    
    
                def handle_input(_input):
                    if "id" in _input and _input not in bad_ids:
                        dependents.add(standardize_asset_name(_input))
    
                    inputs.add(_input)
    
                # get ids from request body
                body = details.get("requestBody")
                if body:
                    try:
                        content = details["requestBody"]["content"]
                        pointer = content.get("application/json", None)
                        if not pointer:
                            pointer = content.get("multipart/form-data", None)
                        if not pointer:
                            pointer = content["application/x-www-form-urlencoded"]
                        ref = pointer["schema"]
                        
                        request_body_schema = resolve_schema_ref(spec, ref)
    
                        # properties
                        properties = request_body_schema.get("properties", None)
                        if properties:
                            print("here1")
                            handle_properties(properties)
    
                        # nestings
                        nested_patterns = ["allOf", "oneOf"]
                        for pat in nested_patterns:
                            if pat in request_body_schema:
                                for prop in request_body_schema[pat]:
                                    if prop.get("properties", None):
                                        print("here2")
                                        handle_properties(prop["properties"])
    
                    except Exception as e:
                        print(f"Error parsing request body {path}", e)
    
                # get ids from parameters
                params = details.get("parameters")
    
                if params:
                    try:
                        for param in params:
                            if param.get("name", None):
                                name = param["name"]
                                handle_input(name)
    
                    except Exception as e:
                        print(f"Error parsing parameters {path}", e)
    
                # get ids from response
                # responses = details.get("responses")
                #
                # if responses:
                #     try:
                #         success_ref = responses["200"]["content"]["application/json"]["schema"]
                #         success_resp_schema = resolve_schema_ref(spec, success_ref)
                #
                #         properties = success_resp_schema.get("properties", None)
                #         if properties:
                #             handle_properties(properties)
                #
                #     except Exception as e:
                #         print(f"Error parsing responses {path}", e)
    
                dependent_assets.update(dependents)
    
                _tag = tags[0] if tags and len(tags) > 0 else None
                all_tags.add(standardize_asset_name(_tag))
                
                curr_asset = standardize_asset_name(get_last_route_segment(path))
                new_node = GraphNode(
                    asset_name=curr_asset,
                    dependent_assets=list(dependents),
                    inputs=list(inputs),
                    route=path,
                    method=method,
                    tag=_tag,
                )
    
                if curr_asset not in node_registry:
                    node_registry[curr_asset] = new_node
                elif len(node_registry[curr_asset].dependent_assets) < len(dependents):
                    node_registry[curr_asset] = new_node
                
            except Exception as e:
                print(path, method)
                print(e)
                continue

    # print(dependent_assets)
    # print(get_assets)
    # print(all_tags)
    _nodes = list(node_registry.values())
    real_nodes = []
    for node in _nodes:
        curr_asset = node.asset_name
        if curr_asset in get_assets or curr_asset in dependent_assets or curr_asset in all_tags:
            real_nodes.append(node)
        else:
            print("removing...", node.asset_name)

    return real_nodes

# %%
from networkx import DiGraph
from typing import List, Dict
import networkx as nx


def build_dependency_tree(_nodes: List[GraphNode]) -> DiGraph:
    _graph = nx.DiGraph()  # Directed graph allows a child to have multiple parents

    # Create all nodes
    for graph_node in _nodes:
        _graph.add_node(graph_node.asset_name)

    # Create edges based on dependencies
    for graph_node in _nodes:
        for dependent_asset in graph_node.dependent_assets:
            _graph.add_edge(dependent_asset, graph_node.asset_name)
        # print("-" * 50)
        # print(graph_node.asset_name)
        # print("children:", graph_node.dependent_assets)

    return _graph

# %%
scale_spec = 'v4-sgp-09-21-24.json-spec-07-04-2024.json'
stripe_spec = 'stripe-openapi.json'

spec = parse_spec(stripe_spec)
nodes = organize_resources(spec)

print(nodes)
graph = build_dependency_tree(nodes)
# Out:
# here account
# here account_links
# here1
# /v1/account_links post
# 'NoneType' object has no attribute 'lower'
# here account_sessions
# here1
# /v1/account_sessions post
# 'NoneType' object has no attribute 'lower'
# here accounts
# here accounts
# here1
# /v1/accounts post
# 'NoneType' object has no attribute 'lower'
# here bank_accounts
# here1
# /v1/accounts/{account}/bank_accounts post
# 'NoneType' object has no attribute 'lower'
# here capabilities
# here external_accounts
# here external_accounts
# here1
# /v1/accounts/{account}/external_accounts post
# 'NoneType' object has no attribute 'lower'
# here login_links
# here1
# /v1/accounts/{account}/login_links post
# 'NoneType' object has no attribute 'lower'
# here people
# here people
# here1
# /v1/accounts/{account}/people post
# 'NoneType' object has no attribute 'lower'
# here persons
# here persons
# here1
# /v1/accounts/{account}/persons post
# 'NoneType' object has no attribute 'lower'
# here reject
# here1
# /v1/accounts/{account}/reject post
# 'NoneType' object has no attribute 'lower'
# here domains
# here domains
# here1
# /v1/apple_pay/domains post
# 'NoneType' object has no attribute 'lower'
# here application_fees
# here refund
# here1
# /v1/application_fees/{id}/refund post
# 'NoneType' object has no attribute 'lower'
# here refunds
# here refunds
# here1
# /v1/application_fees/{id}/refunds post
# 'NoneType' object has no attribute 'lower'
# here secrets
# here secrets
# here1
# /v1/apps/secrets post
# 'NoneType' object has no attribute 'lower'
# here delete
# here1
# /v1/apps/secrets/delete post
# 'NoneType' object has no attribute 'lower'
# here find
# here balance
# here history
# here balance_transactions
# here meter_event_adjustments
# here1
# /v1/billing/meter_event_adjustments post
# 'NoneType' object has no attribute 'lower'
# here meter_events
# here1
# /v1/billing/meter_events post
# 'NoneType' object has no attribute 'lower'
# here meters
# here meters
# here1
# /v1/billing/meters post
# 'NoneType' object has no attribute 'lower'
# here deactivate
# here1
# /v1/billing/meters/{id}/deactivate post
# 'NoneType' object has no attribute 'lower'
# here event_summaries
# here reactivate
# here1
# /v1/billing/meters/{id}/reactivate post
# 'NoneType' object has no attribute 'lower'
# here configurations
# here configurations
# here1
# /v1/billing_portal/configurations post
# 'NoneType' object has no attribute 'lower'
# here sessions
# here1
# /v1/billing_portal/sessions post
# 'NoneType' object has no attribute 'lower'
# here charges
# here charges
# here1
# /v1/charges post
# 'NoneType' object has no attribute 'lower'
# here search
# here capture
# here1
# /v1/charges/{charge}/capture post
# 'NoneType' object has no attribute 'lower'
# here dispute
# here dispute
# here1
# /v1/charges/{charge}/dispute post
# 'NoneType' object has no attribute 'lower'
# here close
# here1
# /v1/charges/{charge}/dispute/close post
# 'NoneType' object has no attribute 'lower'
# here refund
# here1
# /v1/charges/{charge}/refund post
# 'NoneType' object has no attribute 'lower'
# here refunds
# here refunds
# here1
# /v1/charges/{charge}/refunds post
# 'NoneType' object has no attribute 'lower'
# here sessions
# here sessions
# here1
# /v1/checkout/sessions post
# 'NoneType' object has no attribute 'lower'
# here expire
# here1
# /v1/checkout/sessions/{session}/expire post
# 'NoneType' object has no attribute 'lower'
# here line_items
# here orders
# here orders
# here1
# /v1/climate/orders post
# 'NoneType' object has no attribute 'lower'
# here cancel
# here1
# /v1/climate/orders/{order}/cancel post
# 'NoneType' object has no attribute 'lower'
# here products
# here suppliers
# here country_specs
# here coupons
# here coupons
# here1
# /v1/coupons post
# 'NoneType' object has no attribute 'lower'
# here credit_notes
# here credit_notes
# here1
# /v1/credit_notes post
# 'NoneType' object has no attribute 'lower'
# here preview
# here lines
# here lines
# here void
# here1
# /v1/credit_notes/{id}/void post
# 'NoneType' object has no attribute 'lower'
# here customer_sessions
# here1
# /v1/customer_sessions post
# 'NoneType' object has no attribute 'lower'
# here customers
# here customers
# here1
# /v1/customers post
# 'NoneType' object has no attribute 'lower'
# here search
# here balance_transactions
# here balance_transactions
# here1
# /v1/customers/{customer}/balance_transactions post
# 'NoneType' object has no attribute 'lower'
# here bank_accounts
# here bank_accounts
# here1
# /v1/customers/{customer}/bank_accounts post
# 'NoneType' object has no attribute 'lower'
# here verify
# here1
# /v1/customers/{customer}/bank_accounts/{id}/verify post
# 'NoneType' object has no attribute 'lower'
# here cards
# here cards
# here1
# /v1/customers/{customer}/cards post
# 'NoneType' object has no attribute 'lower'
# here cash_balance
# here cash_balance
# here1
# /v1/customers/{customer}/cash_balance post
# 'NoneType' object has no attribute 'lower'
# here cash_balance_transactions
# here discount
# here discount
# here funding_instructions
# here1
# /v1/customers/{customer}/funding_instructions post
# 'NoneType' object has no attribute 'lower'
# here payment_methods
# here sources
# here sources
# here1
# /v1/customers/{customer}/sources post
# 'NoneType' object has no attribute 'lower'
# here verify
# here1
# /v1/customers/{customer}/sources/{id}/verify post
# 'NoneType' object has no attribute 'lower'
# here subscriptions
# here subscriptions
# here1
# /v1/customers/{customer}/subscriptions post
# 'NoneType' object has no attribute 'lower'
# here discount
# here discount
# here tax_ids
# here tax_ids
# here1
# /v1/customers/{customer}/tax_ids post
# 'NoneType' object has no attribute 'lower'
# here disputes
# here close
# here1
# /v1/disputes/{dispute}/close post
# 'NoneType' object has no attribute 'lower'
# here active_entitlements
# here features
# here features
# here1
# /v1/entitlements/features post
# 'NoneType' object has no attribute 'lower'
# here ephemeral_keys
# here1
# /v1/ephemeral_keys post
# 'NoneType' object has no attribute 'lower'
# here events
# here exchange_rates
# here file_links
# here file_links
# here1
# /v1/file_links post
# 'NoneType' object has no attribute 'lower'
# here files
# here files
# here1
# /v1/files post
# 'NoneType' object has no attribute 'lower'
# here accounts
# here disconnect
# here1
# /v1/financial_connections/accounts/{account}/disconnect post
# 'NoneType' object has no attribute 'lower'
# here owners
# here refresh
# here1
# /v1/financial_connections/accounts/{account}/refresh post
# 'NoneType' object has no attribute 'lower'
# here subscribe
# here1
# /v1/financial_connections/accounts/{account}/subscribe post
# 'NoneType' object has no attribute 'lower'
# here unsubscribe
# here1
# /v1/financial_connections/accounts/{account}/unsubscribe post
# 'NoneType' object has no attribute 'lower'
# here sessions
# here1
# /v1/financial_connections/sessions post
# 'NoneType' object has no attribute 'lower'
# here transactions
# here requests
# here requests
# here1
# /v1/forwarding/requests post
# 'NoneType' object has no attribute 'lower'
# here verification_reports
# here verification_sessions
# here verification_sessions
# here1
# /v1/identity/verification_sessions post
# 'NoneType' object has no attribute 'lower'
# here cancel
# here1
# /v1/identity/verification_sessions/{session}/cancel post
# 'NoneType' object has no attribute 'lower'
# here redact
# here1
# /v1/identity/verification_sessions/{session}/redact post
# 'NoneType' object has no attribute 'lower'
# here invoiceitems
# here invoiceitems
# here1
# /v1/invoiceitems post
# 'NoneType' object has no attribute 'lower'
# here invoices
# here invoices
# here1
# /v1/invoices post
# 'NoneType' object has no attribute 'lower'
# here create_preview
# here1
# /v1/invoices/create_preview post
# 'NoneType' object has no attribute 'lower'
# here search
# here upcoming
# here lines
# here add_lines
# here1
# /v1/invoices/{invoice}/add_lines post
# 'NoneType' object has no attribute 'lower'
# here finalize
# here1
# /v1/invoices/{invoice}/finalize post
# 'NoneType' object has no attribute 'lower'
# here lines
# here mark_uncollectible
# here1
# /v1/invoices/{invoice}/mark_uncollectible post
# 'NoneType' object has no attribute 'lower'
# here pay
# here1
# /v1/invoices/{invoice}/pay post
# 'NoneType' object has no attribute 'lower'
# here remove_lines
# here1
# /v1/invoices/{invoice}/remove_lines post
# 'NoneType' object has no attribute 'lower'
# here send
# here1
# /v1/invoices/{invoice}/send post
# 'NoneType' object has no attribute 'lower'
# here update_lines
# here1
# /v1/invoices/{invoice}/update_lines post
# 'NoneType' object has no attribute 'lower'
# here void
# here1
# /v1/invoices/{invoice}/void post
# 'NoneType' object has no attribute 'lower'
# here authorizations
# here approve
# here1
# /v1/issuing/authorizations/{authorization}/approve post
# 'NoneType' object has no attribute 'lower'
# here decline
# here1
# /v1/issuing/authorizations/{authorization}/decline post
# 'NoneType' object has no attribute 'lower'
# here cardholders
# here cardholders
# here1
# /v1/issuing/cardholders post
# 'NoneType' object has no attribute 'lower'
# here cards
# here cards
# here1
# /v1/issuing/cards post
# 'NoneType' object has no attribute 'lower'
# here disputes
# here disputes
# here1
# /v1/issuing/disputes post
# 'NoneType' object has no attribute 'lower'
# here submit
# here1
# /v1/issuing/disputes/{dispute}/submit post
# 'NoneType' object has no attribute 'lower'
# here personalization_designs
# here personalization_designs
# here1
# /v1/issuing/personalization_designs post
# 'NoneType' object has no attribute 'lower'
# here physical_bundles
# here tokens
# here transactions
# here link_account_sessions
# here1
# /v1/link_account_sessions post
# 'NoneType' object has no attribute 'lower'
# here linked_accounts
# here disconnect
# here1
# /v1/linked_accounts/{account}/disconnect post
# 'NoneType' object has no attribute 'lower'
# here owners
# here refresh
# here1
# /v1/linked_accounts/{account}/refresh post
# 'NoneType' object has no attribute 'lower'
# here payment_intents
# here payment_intents
# here1
# /v1/payment_intents post
# 'NoneType' object has no attribute 'lower'
# here search
# here apply_customer_balance
# here1
# /v1/payment_intents/{intent}/apply_customer_balance post
# 'NoneType' object has no attribute 'lower'
# here cancel
# here1
# /v1/payment_intents/{intent}/cancel post
# 'NoneType' object has no attribute 'lower'
# here capture
# here1
# /v1/payment_intents/{intent}/capture post
# 'NoneType' object has no attribute 'lower'
# here confirm
# here1
# /v1/payment_intents/{intent}/confirm post
# 'NoneType' object has no attribute 'lower'
# here increment_authorization
# here1
# /v1/payment_intents/{intent}/increment_authorization post
# 'NoneType' object has no attribute 'lower'
# here verify_microdeposits
# here1
# /v1/payment_intents/{intent}/verify_microdeposits post
# 'NoneType' object has no attribute 'lower'
# here payment_links
# here payment_links
# here1
# /v1/payment_links post
# 'NoneType' object has no attribute 'lower'
# here line_items
# here payment_method_configurations
# here payment_method_configurations
# here1
# /v1/payment_method_configurations post
# 'NoneType' object has no attribute 'lower'
# here payment_method_domains
# here payment_method_domains
# here1
# /v1/payment_method_domains post
# 'NoneType' object has no attribute 'lower'
# here validate
# here1
# /v1/payment_method_domains/{payment_method_domain}/validate post
# 'NoneType' object has no attribute 'lower'
# here payment_methods
# here payment_methods
# here1
# /v1/payment_methods post
# 'NoneType' object has no attribute 'lower'
# here attach
# here1
# /v1/payment_methods/{payment_method}/attach post
# 'NoneType' object has no attribute 'lower'
# here detach
# here1
# /v1/payment_methods/{payment_method}/detach post
# 'NoneType' object has no attribute 'lower'
# here payouts
# here payouts
# here1
# /v1/payouts post
# 'NoneType' object has no attribute 'lower'
# here cancel
# here1
# /v1/payouts/{payout}/cancel post
# 'NoneType' object has no attribute 'lower'
# here reverse
# here1
# /v1/payouts/{payout}/reverse post
# 'NoneType' object has no attribute 'lower'
# here plans
# here plans
# here1
# /v1/plans post
# 'NoneType' object has no attribute 'lower'
# here prices
# here prices
# here1
# /v1/prices post
# 'NoneType' object has no attribute 'lower'
# here search
# here products
# here products
# here1
# /v1/products post
# 'NoneType' object has no attribute 'lower'
# here search
# here features
# here features
# here1
# /v1/products/{product}/features post
# 'NoneType' object has no attribute 'lower'
# here promotion_codes
# here promotion_codes
# here1
# /v1/promotion_codes post
# 'NoneType' object has no attribute 'lower'
# here quotes
# here quotes
# here1
# /v1/quotes post
# 'NoneType' object has no attribute 'lower'
# here accept
# here1
# /v1/quotes/{quote}/accept post
# 'NoneType' object has no attribute 'lower'
# here cancel
# here1
# /v1/quotes/{quote}/cancel post
# 'NoneType' object has no attribute 'lower'
# here computed_upfront_line_items
# here finalize
# here1
# /v1/quotes/{quote}/finalize post
# 'NoneType' object has no attribute 'lower'
# here line_items
# here pdf
# here early_fraud_warnings
# here value_list_items
# here value_list_items
# here1
# /v1/radar/value_list_items post
# 'NoneType' object has no attribute 'lower'
# here value_lists
# here value_lists
# here1
# /v1/radar/value_lists post
# 'NoneType' object has no attribute 'lower'
# here refunds
# here refunds
# here1
# /v1/refunds post
# 'NoneType' object has no attribute 'lower'
# here cancel
# here1
# /v1/refunds/{refund}/cancel post
# 'NoneType' object has no attribute 'lower'
# here report_runs
# here report_runs
# here1
# /v1/reporting/report_runs post
# 'NoneType' object has no attribute 'lower'
# here report_types
# here reviews
# here approve
# here1
# /v1/reviews/{review}/approve post
# 'NoneType' object has no attribute 'lower'
# here setup_attempts
# here setup_intents
# here setup_intents
# here1
# /v1/setup_intents post
# 'NoneType' object has no attribute 'lower'
# here cancel
# here1
# /v1/setup_intents/{intent}/cancel post
# 'NoneType' object has no attribute 'lower'
# here confirm
# here1
# /v1/setup_intents/{intent}/confirm post
# 'NoneType' object has no attribute 'lower'
# here verify_microdeposits
# here1
# /v1/setup_intents/{intent}/verify_microdeposits post
# 'NoneType' object has no attribute 'lower'
# here shipping_rates
# here shipping_rates
# here1
# /v1/shipping_rates post
# 'NoneType' object has no attribute 'lower'
# here scheduled_query_runs
# here sources
# here1
# /v1/sources post
# 'NoneType' object has no attribute 'lower'
# here source_transactions
# here verify
# here1
# /v1/sources/{source}/verify post
# 'NoneType' object has no attribute 'lower'
# here subscription_items
# here subscription_items
# here1
# /v1/subscription_items post
# 'NoneType' object has no attribute 'lower'
# here usage_record_summaries
# here usage_records
# here1
# /v1/subscription_items/{subscription_item}/usage_records post
# 'NoneType' object has no attribute 'lower'
# here subscription_schedules
# here subscription_schedules
# here1
# /v1/subscription_schedules post
# 'NoneType' object has no attribute 'lower'
# here cancel
# here1
# /v1/subscription_schedules/{schedule}/cancel post
# 'NoneType' object has no attribute 'lower'
# here release
# here1
# /v1/subscription_schedules/{schedule}/release post
# 'NoneType' object has no attribute 'lower'
# here subscriptions
# here subscriptions
# here1
# /v1/subscriptions post
# 'NoneType' object has no attribute 'lower'
# here search
# here discount
# here resume
# here1
# /v1/subscriptions/{subscription}/resume post
# 'NoneType' object has no attribute 'lower'
# here calculations
# here1
# /v1/tax/calculations post
# 'NoneType' object has no attribute 'lower'
# here line_items
# here registrations
# here registrations
# here1
# /v1/tax/registrations post
# 'NoneType' object has no attribute 'lower'
# here settings
# here settings
# here1
# /v1/tax/settings post
# 'NoneType' object has no attribute 'lower'
# here create_from_calculation
# here1
# /v1/tax/transactions/create_from_calculation post
# 'NoneType' object has no attribute 'lower'
# here create_reversal
# here1
# /v1/tax/transactions/create_reversal post
# 'NoneType' object has no attribute 'lower'
# here line_items
# here tax_codes
# here tax_ids
# here tax_ids
# here1
# /v1/tax_ids post
# 'NoneType' object has no attribute 'lower'
# here tax_rates
# here tax_rates
# here1
# /v1/tax_rates post
# 'NoneType' object has no attribute 'lower'
# here configurations
# here configurations
# here1
# /v1/terminal/configurations post
# 'NoneType' object has no attribute 'lower'
# here connection_tokens
# here1
# /v1/terminal/connection_tokens post
# 'NoneType' object has no attribute 'lower'
# here locations
# here locations
# here1
# /v1/terminal/locations post
# 'NoneType' object has no attribute 'lower'
# here readers
# here readers
# here1
# /v1/terminal/readers post
# 'NoneType' object has no attribute 'lower'
# here cancel_action
# here1
# /v1/terminal/readers/{reader}/cancel_action post
# 'NoneType' object has no attribute 'lower'
# here process_payment_intent
# here1
# /v1/terminal/readers/{reader}/process_payment_intent post
# 'NoneType' object has no attribute 'lower'
# here process_setup_intent
# here1
# /v1/terminal/readers/{reader}/process_setup_intent post
# 'NoneType' object has no attribute 'lower'
# here refund_payment
# here1
# /v1/terminal/readers/{reader}/refund_payment post
# 'NoneType' object has no attribute 'lower'
# here set_reader_display
# here1
# /v1/terminal/readers/{reader}/set_reader_display post
# 'NoneType' object has no attribute 'lower'
# here confirmation_tokens
# here1
# /v1/test_helpers/confirmation_tokens post
# 'NoneType' object has no attribute 'lower'
# here fund_cash_balance
# here1
# /v1/test_helpers/customers/{customer}/fund_cash_balance post
# 'NoneType' object has no attribute 'lower'
# here authorizations
# here1
# /v1/test_helpers/issuing/authorizations post
# 'NoneType' object has no attribute 'lower'
# here capture
# here1
# /v1/test_helpers/issuing/authorizations/{authorization}/capture post
# 'NoneType' object has no attribute 'lower'
# here expire
# here1
# /v1/test_helpers/issuing/authorizations/{authorization}/expire post
# 'NoneType' object has no attribute 'lower'
# here finalize_amount
# here1
# /v1/test_helpers/issuing/authorizations/{authorization}/finalize_amount post
# 'NoneType' object has no attribute 'lower'
# here increment
# here1
# /v1/test_helpers/issuing/authorizations/{authorization}/increment post
# 'NoneType' object has no attribute 'lower'
# here reverse
# here1
# /v1/test_helpers/issuing/authorizations/{authorization}/reverse post
# 'NoneType' object has no attribute 'lower'
# here deliver
# here1
# /v1/test_helpers/issuing/cards/{card}/shipping/deliver post
# 'NoneType' object has no attribute 'lower'
# here fail
# here1
# /v1/test_helpers/issuing/cards/{card}/shipping/fail post
# 'NoneType' object has no attribute 'lower'
# here return
# here1
# /v1/test_helpers/issuing/cards/{card}/shipping/return post
# 'NoneType' object has no attribute 'lower'
# here ship
# here1
# /v1/test_helpers/issuing/cards/{card}/shipping/ship post
# 'NoneType' object has no attribute 'lower'
# here activate
# here1
# /v1/test_helpers/issuing/personalization_designs/{personalization_design}/activate post
# 'NoneType' object has no attribute 'lower'
# here deactivate
# here1
# /v1/test_helpers/issuing/personalization_designs/{personalization_design}/deactivate post
# 'NoneType' object has no attribute 'lower'
# here reject
# here1
# /v1/test_helpers/issuing/personalization_designs/{personalization_design}/reject post
# 'NoneType' object has no attribute 'lower'
# here create_force_capture
# here1
# /v1/test_helpers/issuing/transactions/create_force_capture post
# 'NoneType' object has no attribute 'lower'
# here create_unlinked_refund
# here1
# /v1/test_helpers/issuing/transactions/create_unlinked_refund post
# 'NoneType' object has no attribute 'lower'
# here refund
# here1
# /v1/test_helpers/issuing/transactions/{transaction}/refund post
# 'NoneType' object has no attribute 'lower'
# here expire
# here1
# /v1/test_helpers/refunds/{refund}/expire post
# 'NoneType' object has no attribute 'lower'
# here present_payment_method
# here1
# /v1/test_helpers/terminal/readers/{reader}/present_payment_method post
# 'NoneType' object has no attribute 'lower'
# here test_clocks
# here test_clocks
# here1
# /v1/test_helpers/test_clocks post
# 'NoneType' object has no attribute 'lower'
# here advance
# here1
# /v1/test_helpers/test_clocks/{test_clock}/advance post
# 'NoneType' object has no attribute 'lower'
# here fail
# here1
# /v1/test_helpers/treasury/inbound_transfers/{id}/fail post
# 'NoneType' object has no attribute 'lower'
# here return
# here1
# /v1/test_helpers/treasury/inbound_transfers/{id}/return post
# 'NoneType' object has no attribute 'lower'
# here succeed
# here1
# /v1/test_helpers/treasury/inbound_transfers/{id}/succeed post
# 'NoneType' object has no attribute 'lower'
# here fail
# here1
# /v1/test_helpers/treasury/outbound_payments/{id}/fail post
# 'NoneType' object has no attribute 'lower'
# here post
# here1
# /v1/test_helpers/treasury/outbound_payments/{id}/post post
# 'NoneType' object has no attribute 'lower'
# here return
# here1
# /v1/test_helpers/treasury/outbound_payments/{id}/return post
# 'NoneType' object has no attribute 'lower'
# here fail
# here1
# /v1/test_helpers/treasury/outbound_transfers/{outbound_transfer}/fail post
# 'NoneType' object has no attribute 'lower'
# here post
# here1
# /v1/test_helpers/treasury/outbound_transfers/{outbound_transfer}/post post
# 'NoneType' object has no attribute 'lower'
# here return
# here1
# /v1/test_helpers/treasury/outbound_transfers/{outbound_transfer}/return post
# 'NoneType' object has no attribute 'lower'
# here received_credits
# here1
# /v1/test_helpers/treasury/received_credits post
# 'NoneType' object has no attribute 'lower'
# here received_debits
# here1
# /v1/test_helpers/treasury/received_debits post
# 'NoneType' object has no attribute 'lower'
# here tokens
# here1
# /v1/tokens post
# 'NoneType' object has no attribute 'lower'
# here topups
# here topups
# here1
# /v1/topups post
# 'NoneType' object has no attribute 'lower'
# here cancel
# here1
# /v1/topups/{topup}/cancel post
# 'NoneType' object has no attribute 'lower'
# here transfers
# here transfers
# here1
# /v1/transfers post
# 'NoneType' object has no attribute 'lower'
# here reversals
# here reversals
# here1
# /v1/transfers/{id}/reversals post
# 'NoneType' object has no attribute 'lower'
# here credit_reversals
# here credit_reversals
# here1
# /v1/treasury/credit_reversals post
# 'NoneType' object has no attribute 'lower'
# here debit_reversals
# here debit_reversals
# here1
# /v1/treasury/debit_reversals post
# 'NoneType' object has no attribute 'lower'
# here financial_accounts
# here financial_accounts
# here1
# /v1/treasury/financial_accounts post
# 'NoneType' object has no attribute 'lower'
# here features
# here features
# here1
# /v1/treasury/financial_accounts/{financial_account}/features post
# 'NoneType' object has no attribute 'lower'
# here inbound_transfers
# here inbound_transfers
# here1
# /v1/treasury/inbound_transfers post
# 'NoneType' object has no attribute 'lower'
# here cancel
# here1
# /v1/treasury/inbound_transfers/{inbound_transfer}/cancel post
# 'NoneType' object has no attribute 'lower'
# here outbound_payments
# here outbound_payments
# here1
# /v1/treasury/outbound_payments post
# 'NoneType' object has no attribute 'lower'
# here cancel
# here1
# /v1/treasury/outbound_payments/{id}/cancel post
# 'NoneType' object has no attribute 'lower'
# here outbound_transfers
# here outbound_transfers
# here1
# /v1/treasury/outbound_transfers post
# 'NoneType' object has no attribute 'lower'
# here cancel
# here1
# /v1/treasury/outbound_transfers/{outbound_transfer}/cancel post
# 'NoneType' object has no attribute 'lower'
# here received_credits
# here received_debits
# here transaction_entries
# here transactions
# here webhook_endpoints
# here webhook_endpoints
# here1
# /v1/webhook_endpoints post
# 'NoneType' object has no attribute 'lower'
# []

# %%
# Dictionary to store anytree nodes
from anytree import Node, RenderTree

# Dictionary to store anytree nodes
nodes_dict = defaultdict(lambda: None)
sink_nodes = [node for node in graph.nodes() if graph.out_degree(node) == 0]

# Function to build the tree using anytree
def build_tree_for_node(_graph, _node):
    # Initialize the root node for the tree
    _root = Node(_node)
    nodes_dict[_node] = _root
    # Use a stack for DFS
    stack = [_node]
    visited = set()

    while stack:
        node = stack.pop()
        if node not in visited:
            visited.add(node)
            for pred in _graph.predecessors(node):
                if pred not in nodes_dict:
                    nodes_dict[pred] = Node(pred, parent=nodes_dict[node])
                else:
                    nodes_dict[pred].parent = nodes_dict[node]
                stack.append(pred)
    return _root


def print_tree(_root: Node):
    print(f"Tree for {sink_node}:")
    for pre, _, node in RenderTree(_root):
        print("%s%s" % (pre, node.name))

# Visualize trees for each sink node
for sink_node in sink_nodes:
    root = build_tree_for_node(graph, sink_node)
    print_tree(root)
    print("\n" + "="*40)  # Separator between trees

# %%
node_assets = [str(node) for node in graph.nodes()]
node_assets
# Out:
# []

# %%
asset_tree = build_tree_for_node(graph, "test-case")

print(print_tree(asset_tree))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Desktop/Development/parrot/venv/lib/python3.11/site-packages/networkx/classes/digraph.py:936, in DiGraph.predecessors(self, n)
#     935 try:
# --> 936     return iter(self._pred[n])
#     937 except KeyError as err:
#
# KeyError: 'test-case'
#
# The above exception was the direct cause of the following exception:
#
# NetworkXError                             Traceback (most recent call last)
# Cell In[96], line 1
# ----> 1 asset_tree = build_tree_for_node(graph, "test-case")
#       3 print(print_tree(asset_tree))
#
# Cell In[94], line 21, in build_tree_for_node(_graph, _node)
#      19 if node not in visited:
#      20     visited.add(node)
# ---> 21     for pred in _graph.predecessors(node):
#      22         if pred not in nodes_dict:
#      23             nodes_dict[pred] = Node(pred, parent=nodes_dict[node])
#
# File ~/Desktop/Development/parrot/venv/lib/python3.11/site-packages/networkx/classes/digraph.py:938, in DiGraph.predecessors(self, n)
#     936     return iter(self._pred[n])
#     937 except KeyError as err:
# --> 938     raise NetworkXError(f"The node {n} is not in the digraph.") from err
#
# NetworkXError: The node test-case is not in the digraph.

# %%
assert False

# %%
hello_world = 'hello world (placeholder)'
